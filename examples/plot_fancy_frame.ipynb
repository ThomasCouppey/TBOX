# %% [markdown]
# # Plot gradient arrow

# %%
import sys
sys.path.append("../")

from tbox.plot_utils import add_fancy_frame
import matplotlib.pyplot as plt
from matplotlib.figure import SubFigure
from matplotlib.colors import ListedColormap
import numpy as np


fig,ax = plt.subplots()
n=100
ax.plot(np.cos(np.linspace(0,4*np.pi,n)), np.sin(np.linspace(0,4*np.pi,n)))

fancy = add_fancy_frame(fig, pad=0.03)
